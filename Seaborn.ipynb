# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
# %matplotlib inline

# %%
x = np.random.randn(1000)
plt.figure()
sns.distplot(x)
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = np.random.randn(1000)
plt.figure()
sns.distplot(x, color = 'green', hist =False)
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = np.random.randn(1000)
plt.figure()
sns.distplot(x, color = 'green', hist =False, vertical = True)
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Density'>

# %%
col1 = np.linspace(0,10,1000)
col2 = np.sin(col1)
df = pd.DataFrame({'C1' : col1, 'C2' : col2})
df.head(10)
# Out:
#         C1        C2
# 0  0.00000  0.000000
# 1  0.01001  0.010010
# 2  0.02002  0.020019
# 3  0.03003  0.030026
# 4  0.04004  0.040029
# 5  0.05005  0.050029
# 6  0.06006  0.060024
# 7  0.07007  0.070013
# 8  0.08008  0.079995
# 9  0.09009  0.089968

# %%
plt.figure(figsize = (8,4),dpi =200)
plt.style.use('seaborn-darkgrid')
sns.lineplot(df.C1, df.C2)
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='C1', ylabel='C2'>

# %%
plt.figure(figsize=(12,6),dpi = 200)
sns.set(rc = {'axes.facecolor' : '#283747', 'axes.grid' : False, 'xtick.labelsize' : 16, 'ytick.labelsize':16})
sns.lineplot(x = df.C1, y = df.C2, data = df, linewidth = 3.0, color = '#FF5722')
sns.lineplot(x = df.C1, y = df.C2 + 1, data = df, linewidth = 3.0, color = '#FFEB3B')
# Out:
# <AxesSubplot:xlabel='C1', ylabel='C2'>

# %% [markdown]
# mpl.rcParams.update(mpl.ncParamsdefault)
# %matplotlib inline
# sns.lineplot(x = df.C1, y = df.C2, data = df, linewidth = 3.0, color = '#FF5722')

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline
sns.lineplot(x = df.C1, y = df.C2, data = df, linewidth = 3.0, color = '#FF5722')
# Out:
# <AxesSubplot:xlabel='C1', ylabel='C2'>

# %%
plt.figure(figsize=(12,5),dpi = 200)
sns.set(rc = {'axes.facecolor' : 'white', 'axes.grid' : False, 'xtick.labelsize' : 16, 'ytick.labelsize':16})
sns.lineplot(x = df.C1, y = df.C2, data = df, linewidth = 3.0, color = '#FF5722', label = 'SinWave')
sns.lineplot(x = df.C1, y = df.C2 + 1, data = df, linewidth = 3.0, color = '#FFEB3B', label = 'SinWave + 1')
plt.title('Cool stuff with seaborn')
plt.xlabel('X')
plt.ylabel('Sin(X)')
# Out:
# Text(0, 0.5, 'Sin(X)')

# %% [markdown]
# # ------------------------------------------------------

# %%
auto = pd.read_csv('Automobile_Data.csv')
auto.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
auto.replace('?', np.nan, inplace= True)

# %%
auto.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
auto.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
auto.nunique()
# Out:
# symboling              6
# normalized-losses     51
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           2
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  38
# stroke                36
# compression-ratio     32
# horsepower            59
# peak-rpm              23
# city-mpg              29
# highway-mpg           30
# price                186
# dtype: int64

# %%
print('Fuel Type       : ',auto['fuel-type'].unique())
print('Body Style      : ',auto['body-style'].unique())
print('Drive Wheels    : ',auto['drive-wheels'].unique())
print('Engine Type     : ',auto['engine-type'].unique())
print('Fuel System     : ',auto['fuel-system'].unique())
print('Engine Location : ',auto['engine-location'].unique())
# Out:
# Fuel Type       :  ['gas' 'diesel']
# Body Style      :  ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# Drive Wheels    :  ['rwd' 'fwd' '4wd']
# Engine Type     :  ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# Fuel System     :  ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# Engine Location :  ['front' 'rear']

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'curb-weight', data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='curb-weight'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'city-mpg', data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='city-mpg'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'city-mpg', hue = 'fuel-type', data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='city-mpg'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'curb-weight', hue = 'drive-wheels', data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='curb-weight'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'curb-weight', hue = 'body-style', data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='curb-weight'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'curb-weight', style = 'drive-wheels', data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='curb-weight'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'city-mpg', hue = 'fuel-type',style = 'fuel-type', markers = True, data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='city-mpg'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.lineplot(x = 'engine-size', y = 'city-mpg', hue = 'fuel-type',style = 'fuel-type', markers = ['*','>'], data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='city-mpg'>

# %%
plt.figure(figsize =(8,5), dpi = 300)
sns.scatterplot(x = 'engine-size', y = 'city-mpg', hue = 'body-style',style = 'fuel-type', data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='city-mpg'>

# %%
plt.figure(figsize = (8,5),dpi = 300)
sns.scatterplot(x = 'engine-size', y = 'city-mpg',hue = 'body-style',style = 'num-of-cylinders',data = auto)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='city-mpg'>

# %%
plt.figure(figsize = (9,4), dpi =300)
sns.barplot(auto['body-style'],auto['city-mpg'])
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='city-mpg'>

# %%
plt.figure(figsize = (9,4), dpi =300)
sns.barplot(auto['num-of-cylinders'],auto['city-mpg'])
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num-of-cylinders', ylabel='city-mpg'>

# %%
plt.figure(figsize = (9,6), dpi =300)
sns.barplot(auto['city-mpg'],auto['num-of-cylinders'])
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='city-mpg', ylabel='num-of-cylinders'>

# %%
plt.figure(figsize = (9,6), dpi =300)
sns.barplot(auto['city-mpg'],auto['num-of-cylinders'])
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='city-mpg', ylabel='num-of-cylinders'>

# %%
plt.figure(figsize =(9,6),dpi =300)
sns.countplot(auto['body-style'])
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.relplot(x = 'engine-size', y = 'curb-weight', data =auto, kind='line', height = 6, aspect = 1.5)

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.relplot(x = 'engine-size', y = 'curb-weight', data =auto, kind='scatter', height = 6, aspect = 1.5)

# %%
plt.figure(figsize = (8,4), dpi =300)
sns.relplot(auto['engine-size'],y = 'curb-weight', data =auto, kind='scatter', col='fuel-type')
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (8,4),dpi = 300)
sns.relplot(x = 'engine-size', y = 'curb-weight', data = auto, kind = 'scatter',col = 'body-style', col_wrap=3)

# %%
plt.figure(figsize = (8,4),dpi = 300)
sns.relplot(x = 'engine-size', y = 'curb-weight', data = auto, kind = 'scatter',col = 'fuel-type', row = 'body-style')

# %%
plt.figure(figsize = (8,4),dpi = 300)
sns.violinplot(auto['body-style'], auto['city-mpg'])
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='city-mpg'>

# %%
plt.figure(figsize = (8,4),dpi = 300)
sns.boxplot(auto['body-style'], auto['city-mpg'])
# Out:
# C:\Users\celia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='city-mpg'>
